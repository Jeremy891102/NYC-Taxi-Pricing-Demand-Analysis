# %% [markdown]
# ## 📌 Q4 Preparation: Price Elasticity Master Table
#
# This section creates the **master table** that Q4 (Revenue Analysis) will use for all simulations.
#
# ### Required Fields for Q4:
#
# - `PULocationID` - Pickup zone ID
# - `pickup_hour` - Hour of day (0-23)
# - `avg_price` - Average price per mile
# - `trip_count` - Number of trips (demand proxy)
# - `trip_miles` - Average trip distance
# - `elasticity_high` - Price elasticity (High vs Medium)
# - `elasticity_low` - Price elasticity (Low vs Medium)
# - `demand_level` - Low / Medium / High demand classification
# - `journey_type` - Trip length category (Short / Medium / Long)
# - `location_type` - Manhattan / Non-Manhattan
# - `peak_offpeak_elasticity` - Elasticity by peak/off-peak status
#
# 👉 **This is the single source of truth for all Q4 simulations.**

# %% [markdown]
# ---
#
# ## ✅ Q4 Ready: Master Table Summary
#
# ### 📌 What Q4 Gets
#
# The `price_elasticity_master` table contains **all necessary information** for revenue simulations:
#
# 1. **Base Metrics** (from panel aggregation):
#    - `avg_price`: Average price per mile for each (zone, hour)
#    - `trip_count`: Average trip count (demand proxy)
#    - `trip_miles`: Average trip distance
#
# 2. **Price Sensitivity** (from Q3-2):
#    - `elasticity_high`: How demand reacts when price increases
#    - `elasticity_low`: How demand reacts when price decreases
#
# 3. **Contextual Classifications**:
#    - `demand_level`: Low / Medium / High (zone-specific quantiles)
#    - `journey_type`: Short / Medium / Long (trip length category)
#    - `location_type`: Manhattan / Non-Manhattan
#    - `peak_offpeak`: Peak / Off-Peak / Medium (based on demand_level)
#    - `peak_offpeak_elasticity`: Elasticity value for peak/offpeak analysis
#
# ### 🎯 How Q4 Will Use This
#
# Q4 can now:
# - Filter by zone, hour, demand level, journey type, or location type
# - Simulate price changes using `elasticity_high` and `elasticity_low`
# - Calculate revenue impact: `Revenue = Price × Demand × Distance`
# - Identify optimal pricing strategies for different segments
#
# 👉 **All Q4 simulations start from this single master table.**
